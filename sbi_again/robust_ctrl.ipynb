# %%
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np
import torch

from train_dynamics import generate_data
from policygradient import PolicyGradientOptions, run_policy_gradient, Regularizer
from ltimult import LQRSysMult

# %%
device = "cpu"
cached_fn = os.path.join("dynamics_trained", "dynamics.nf")
with open(cached_fn, "rb") as f:
    encoder = pickle.load(f)
encoder.to(device)
# Out:
# Flow(
#   (_transform): CompositeTransform(
#     (_transforms): ModuleList(
#       (0): PiecewiseRationalQuadraticCouplingTransform(
#         (transform_net): ResidualNet(
#           (initial_layer): Linear(in_features=15, out_features=50, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x ResidualBlock(
#               (context_layer): Linear(in_features=12, out_features=50, bias=True)
#               (linear_layers): ModuleList(
#                 (0-1): 2 x Linear(in_features=50, out_features=50, bias=True)
#               )
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (final_layer): Linear(in_features=50, out_features=87, bias=True)
#         )
#       )
#       (1): LULinear()
#       (2): PiecewiseRationalQuadraticCouplingTransform(
#         (transform_net): ResidualNet(
#           (initial_layer): Linear(in_features=15, out_features=50, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x ResidualBlock(
#               (context_layer): Linear(in_features=12, out_features=50, bias=True)
#               (linear_layers): ModuleList(
#                 (0-1): 2 x Linear(in_features=50, out_features=50, bias=True)
#               )
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (final_layer): Linear(in_features=50, out_features=87, bias=True)
#         )
#       )
#       (3): LULinear()
#       (4): PiecewiseRationalQuadraticCouplingTransform(
#         (transform_net): ResidualNet(
#           (initial_layer): Linear(in_features=15, out_features=50, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x ResidualBlock(
#               (context_layer): Linear(in_features=12, out_features=50, bias=True)
#               (linear_layers): ModuleList(
#                 (0-1): 2 x Linear(in_features=50, out_features=50, bias=True)
#               )
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (final_layer): Linear(in_features=50, out_features=87, bias=True)
#         )
#       )
#       (5): LULinear()
#       (6): PiecewiseRationalQuadraticCouplingTransform(
#         (transform_net): ResidualNet(
#           (initial_layer): Linear(in_features=15, out_features=50, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x ResidualBlock(
#               (context_layer): Linear(in_features=12, out_features=50, bias=True)
#               (linear_layers): ModuleList(
#                 (0-1): 2 x Linear(in_features=50, out_features=50, bias=True)
#               )
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (final_layer): Linear(in_features=50, out_features=87, bias=True)
#         )
#       )
#       (7): LULinear()
#       (8): PiecewiseRationalQuadraticCouplingTransform(
#         (transform_net): ResidualNet(
#           (initial_layer): Linear(in_features=15, out_features=50, bias=True)
#           (blocks): ModuleList(
#             (0-1): 2 x ResidualBlock(
#               (context_layer): Linear(in_features=12, out_features=50, bias=True)
#               (linear_layers): ModuleList(
#                 (0-1): 2 x Linear(in_features=50, out_features=50, bias=True)
#               )
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (final_layer): Linear(in_features=50, out_features=87, bias=True)
#         )
#       )
#       (9): LULinear()
#     )
#   )
#   (_distribution): StandardNormal()
#   (_embedding_net): Identity()
# )

# %%
def calc_scores(xs, Cs, k=10):
    cal_samples = encoder.sample(k, xs).detach().cpu().numpy()
    cal_samples = cal_samples.reshape((cal_samples.shape[0], k, 2, 3))
    cal_tiled = np.transpose(np.tile(Cs.detach().cpu().numpy(), (k, 1, 1, 1)), (1, 0, 2, 3))
    cal_diff = cal_samples - cal_tiled
    cal_norms = np.linalg.norm(cal_diff, ord=2, axis=(2,3))
    return np.min(cal_norms, axis=-1)

# %%
# C in R^2x3
cal_sims = 1_000
cal_C_hats, cal_x = generate_data(cal_sims)
cal_C_hats = cal_C_hats.reshape((cal_sims, 2, 3))
cal_scores = calc_scores(cal_x, cal_C_hats)
q_hat = np.quantile(cal_scores, q = 0.95)
# Out:
# /home/yppatel/anaconda3/envs/chig/lib/python3.8/site-packages/nflows/transforms/lu.py:80: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at ../aten/src/ATen/native/BatchLinearAlgebra.cpp:2191.)
#   outputs, _ = torch.triangular_solve(

# %%
k = 10
test_sims = 1
_, test_x = generate_data(test_sims)
test_C_hats = encoder.sample(k, test_x).detach().cpu().numpy()
test_C_hats = test_C_hats.reshape((test_C_hats.shape[0], k, 2, 3))

# %%
# Get system dynamics from side information
C_hat = test_C_hats[0][0]
A = C_hat[:,:2]
B = C_hat[:,2:]

# System problem data
Q = np.eye(A.shape[-1])
R = np.eye(B.shape[-1])
S0 = np.eye(A.shape[-1])

# useless for us, but just keep to use library code
Aa = np.zeros(A.shape)
Aa = Aa[:, :, np.newaxis]
Bb = np.zeros(B.shape)
Bb = Bb[:, :, np.newaxis]
a = np.zeros((1, 1))
b = np.zeros((1, 1))

# %%
opt_steps = 5_000

# Start with an initially stabilizing (feasible) controller;
# for this example the system is open-loop mean-square stable
K_star = np.zeros([B.shape[1], A.shape[1]])

for opt_step in range(opt_steps):
    SS = LQRSysMult(A, B, a, Aa, b, Bb, Q, R, S0)
    SS.setK(K_star)
    PGO = PolicyGradientOptions(epsilon=(1e-2) * SS.Kare.size,
                                eta=1e-3,
                                max_iters=1,
                                disp_stride=1,
                                keep_hist=True,
                                opt_method='proximal',
                                keep_opt='last',
                                step_direction='gradient',
                                stepsize_method='constant',
                                exact=True,
                                regularizer=Regularizer('vec1'),
                                regweight=0.0,
                                stop_crit='gradient',
                                fbest_repeat_max=0,
                                display_output=True,
                                display_inplace=True,
                                slow=False)

    # Run (regularized) policy gradient
    run_policy_gradient(SS, PGO)
    K_star = SS.K

    # Print the regularized optimal gains (from proximal gradient optimization)
    # and the unregularized optimal gains (from solving a Riccati equation)
    print('Optimized sparse gains')
    print(SS.K)
    print('Riccati gains')
    print(SS.Kare)
# Out:
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  6
+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00825996  0.04007821]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.113e-01 / 2.000e-02 | 4.293e+00 | 4.293e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00834699  0.04048016]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.087e-01 / 2.000e-02 | 4.293e+00 | 4.293e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00843358  0.04087957]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.061e-01 / 2.000e-02 | 4.293e+00 | 4.293e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00851973  0.04127647]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.036e-01 / 2.000e-02 | 4.293e+00 | 4.293e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00860545  0.04167087]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.011e-01 / 2.000e-02 | 4.292e+00 | 4.292e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00869074  0.04206278]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.986e-01 / 2.000e-02 | 4.292e+00 | 4.292e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00877559  0.04245223]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.961e-01 / 2.000e-02 | 4.292e+00 | 4.292e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00886002  0.04283922]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.936e-01 / 2.000e-02 | 4.292e+00 | 4.292e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00894402  0.04322378]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.912e-01 / 2.000e-02 | 4.292e+00 | 4.292e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00902759  0.04360593]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.887e-01 / 2.000e-02 | 4.292e+00 | 4.292e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00911075  0.04398567]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.863e-01 / 2.000e-02 | 4.291e+00 | 4.291e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00919349  0.04436302]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.839e-01 / 2.000e-02 | 4.291e+00 | 4.291e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00927581  0.044738  ]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.815e-01 / 2.000e-02 | 4.291e+00 | 4.291e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00935772  0.04511062]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.791e-01 / 2.000e-02 | 4.291e+00 | 4.291e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00943922  0.0454809 ]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.768e-01 / 2.000e-02 | 4.291e+00 | 4.291e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.00952031  0.04584886]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.744e-01 / 2.000e-02 | 4.291e+00 | 4.291e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# ...
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.0236479   0.09852487]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.271e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02366451  0.09856421]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.246e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02368106  0.09860332]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.221e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02369755  0.09864218]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.197e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02371398  0.0986808 ]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.173e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02373034  0.09871918]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.148e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02374664  0.09875733]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.124e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02376288  0.09879524]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.100e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02377906  0.09883292]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.077e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02379518  0.09887036]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.053e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02381123  0.09890758]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.030e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02382723  0.09894456]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  4.006e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02384316  0.09898132]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.983e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02385904  0.09901785]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.960e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.007 seconds
# Optimized sparse gains
# [[-0.02387485  0.09905415]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.937e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02389061  0.09909023]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.914e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.0239063   0.09912609]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.892e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02392194  0.09916173]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.869e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02393752  0.09919714]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.847e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02395304  0.09923234]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.825e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.008 seconds
# Optimized sparse gains
# [[-0.0239685   0.09926732]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.802e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.0239839   0.09930209]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.781e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02399924  0.09933664]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.759e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02401453  0.09937098]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.737e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02402976  0.0994051 ]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  | Sparsity
#                                                                                                         1 |  3.715e-02 / 2.000e-02 | 4.279e+00 | 4.279e+00 |            inf | 1.000e-03 |   0.00%
# Max iterations exceeded, stopping optimization
# Policy gradient descent optimization completed after 1 iterations, 0.006 seconds
# Optimized sparse gains
# [[-0.02404494  0.09943902]]
# Riccati gains
# [[-0.02881471  0.10471411]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/yppatel/crc/sbi_again/robust_ctrl.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> PGO = PolicyGradientOptions(epsilon=(1e-2) * SS.Kare.size,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>                             eta=1e-3,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>                             max_iters=1,
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>                             display_inplace=True,
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>                             slow=False)
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> # Run (regularized) policy gradient
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> run_policy_gradient(SS, PGO)
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> K_star = SS.K
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> # Print the regularized optimal gains (from proximal gradient optimization)
#      <a href='vscode-notebook-cell://ssh-remote%2Bdeeplearning-01.stat.lsa.umich.edu/home/yppatel/crc/sbi_again/robust_ctrl.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> # and the unregularized optimal gains (from solving a Riccati equation)
#
# File ~/crc/sbi_again/policygradient.py:489, in run_policy_gradient(SS, PGO)
#     487 stop_early = False
#     488 iterc = 0
# --> 489 sleep(0.5)
#     490 t_start = time()
#     492 headerstr = 'Iteration | Stop quant / threshold |  Curr obj |  Best obj | Norm of gain delta | Stepsize  '
#
# KeyboardInterrupt:
